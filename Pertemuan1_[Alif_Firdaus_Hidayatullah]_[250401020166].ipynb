# %% [markdown]
# <a href="https://colab.research.google.com/github/freezetea/data-science-2024-Public-/blob/main/Pertemuan1_%5BAlif_Firdaus_Hidayatullah%5D_%5B250401020166%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")

# SEL 2: Variabel & tipe data
nama = "Mahasiswa Informatika"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Budi","Informatika",2024))
# Out:
# Hello, Data Science!
# Halo, Mahasiswa Informatika angkatan 2024!
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub
# Budi | Informatika | 2024

# %% [markdown]
# <a href="https://colab.research.google.com/github/freezetea/data-science-2026/blob/main/Pertemuan1_%5BAlif_Firdaus_Hidayatullah%5D_%5B250401020166%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana
print("Hello, Data Science!")

# SEL 2: Variabel & tipe data
nama = "Alif Firdaus Hidayatullah"
angkatan = 2025
jurusan = "Informatika"
print(f"Hi, perkenalkan Saya {nama} dari {jurusan} angkatan {angkatan}!")

# SEL 3: List & perulangan
print("Berikut Tools Data Science yang akan kita pelajari:")
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Alif Firdaus","Informatika",2025))
# Out:
# Hello, Data Science!
# Hi, perkenalkan Saya Alif Firdaus Hidayatullah dari Informatika angkatan 2025!
# Berikut Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub
# Alif Firdaus | Informatika | 2025
